# %% [markdown]
# ## Practical - 2
#
# ## Trend Values Using Least-Squares
#
# ## Problem

# %% [markdown]
# ![Prac-2.png](attachment:Prac-2.png)

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Code

# %%
Years=[1993,1995,1996,1997,1998,1999,2002]
Production=[77,88,94,85,91,98,90]

# %%
m,c=np.polyfit(Years,Production,deg=1)

# %%
m,c
# Out:
# (1.3764044943820066, -2659.8764044943505)

# %%
y_line=[m*i+c for i in Years]

# %% [markdown]
# ## Trend values

# %%
y_line
# Out:
# [83.29775280898866,
#  86.05056179775283,
#  87.4269662921347,
#  88.80337078651655,
#  90.17977528089887,
#  91.55617977528073,
#  95.68539325842676]

# %%
plt.scatter(Years,Production)
plt.plot(Years,y_line,'r')
