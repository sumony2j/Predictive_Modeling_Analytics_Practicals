# %% [markdown]
# ## Practical - 6
#
# ## T-test
#
# ## Problem

# %% [markdown]
# ![Prac-6.png](attachment:Prac-6.png)

# %% [markdown]
# ## Libraries

# %%
from scipy import stats
import pingouin as pg

# %% [markdown]
# ## Code

# %%
alpha = 0.05
t_val = 1.833

# %%
weights_1st_month = [50,60,58,52,51,62,58,55,50,65]
weights_2nd_month = [56,58,68,61,56,59,64,60,50,62]

# %%
t_result,p_val = stats.ttest_rel(weights_1st_month,weights_2nd_month)

# %%
t_result,p_val
# Out:
# (-2.129647923401715, 0.062056988380769965)

# %%
if p_val <= alpha:
    print('Reject Null Hypothesis')
else:
    print('Accept Null Hypothesis')
# Out:
# Accept Null Hypothesis

# %% [markdown]
# ## Alternative Way

# %%
pg.ttest(weights_1st_month,weights_2nd_month,paired=True)
# Out:
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -2.129648    9   two-sided  0.062057  [-6.81, 0.21]  0.643549  1.498
#
#            power
# T-test  0.443569
