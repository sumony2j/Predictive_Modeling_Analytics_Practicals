# %% [markdown]
# ## Practical - 4
#
# ## Linear Regression Equation
#
# ## Problem

# %% [markdown]
# ![Prac-4.png](attachment:Prac-4.png)

# %% [markdown]
# ## Libraries

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# %% [markdown]
# ## Code

# %%
x1 = [0.58,0.86,0.29,0.20,0.56,0.28,0.08,0.41,0.22,0.35,0.59,0.22,0.26,0.12,0.65,0.70,0.30,0.70,0.39,0.72,0.45,0.81,0.04,0.20,0.95]
x2 = [0.71,0.13,0.79,0.20,0.56,0.92,0.01,0.60,0.70,0.73,0.13,0.96,0.27,0.21,0.88,0.30,0.15,0.09,0.17,0.25,0.30,0.32,0.82,0.98,0.00]
y = [1.45,1.93,0.81,0.61,1.55,0.95,0.45,1.14,0.74,0.98,1.41,0.81,0.89,0.68,1.39,1.53,0.91,1.49,1.38,1.73,1.11,1.68,0.66,0.69,1.98]

# %%
df = pd.DataFrame({'X1':x1,'X2':x2,'Y':y})

# %%
df
# Out:
#       X1    X2     Y
# 0   0.58  0.71  1.45
# 1   0.86  0.13  1.93
# 2   0.29  0.79  0.81
# 3   0.20  0.20  0.61
# 4   0.56  0.56  1.55
# 5   0.28  0.92  0.95
# 6   0.08  0.01  0.45
# 7   0.41  0.60  1.14
# 8   0.22  0.70  0.74
# 9   0.35  0.73  0.98
# 10  0.59  0.13  1.41
# 11  0.22  0.96  0.81
# 12  0.26  0.27  0.89
# 13  0.12  0.21  0.68
# 14  0.65  0.88  1.39
# 15  0.70  0.30  1.53
# 16  0.30  0.15  0.91
# 17  0.70  0.09  1.49
# 18  0.39  0.17  1.38
# 19  0.72  0.25  1.73
# 20  0.45  0.30  1.11
# 21  0.81  0.32  1.68
# 22  0.04  0.82  0.66
# 23  0.20  0.98  0.69
# 24  0.95  0.00  1.98

# %%
x= df[['X1','X2']]
y = df['Y']

# %%
lm = LinearRegression().fit(x,y)

# %%
lm.intercept_
# Out:
# 0.43354711505518506

# %%
lm.coef_
# Out:
# array([1.65299345, 0.00394488])

# %%
print(f'The estimated linear regression equation will be :- y = {lm.intercept_} + {lm.coef_[0]}*x1 + {lm.coef_[1]}*x2')
# Out:
# The estimated linear regression equation will be :- y = 0.43354711505518506 + 1.6529934509657123*x1 + 0.0039448751847171865*x2
